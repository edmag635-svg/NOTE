# %% [markdown]
# <a href="https://colab.research.google.com/github/edmag635-svg/NOTE/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importar librerias para el programa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# parte 1
# edwin  magdaleno dominguez 2177965 IMC

# %%
# importar dataset

Dataset=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv")

# %% [markdown]
# 3 parte

# %%
#mostrar el tipo de datos en las columnas y los primeros 5 datos de la tabla
columna=["mpg","cylinders","displacement","horsepower","weight","acceleration","model_year","origin","name"] #asignar variable
print("tipos de datos en las columnas:  ")
print(Dataset[columna].dtypes) #escribir los tipos de datos de las columnas
Dataset.head(5) #mostrar los primeros 5 datos de la tabla
# Out:
# tipos de datos en las columnas:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# ...

# %% [markdown]
# 4

# %%
mediana=Dataset["horsepower"].median()
print(mediana)
Dataset["horsepower"]=Dataset["horsepower"].fillna(mediana)
# Out:
# 93.5

# %% [markdown]
# 5

# %%
Dataset["relacion_peso_potencia"]=Dataset["weight"]/Dataset["horsepower"]
Dataset.head(5)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  relacion_peso_potencia
# 0          70    usa  chevrolet chevelle malibu               26.953846
# 1          70    usa          buick skylark 320               22.381818
# 2          70    usa         plymouth satellite               22.906667
# 3          70    usa              amc rebel sst               22.886667
# 4          70    usa                ford torino               24.635714

# %% [markdown]
# parte 2

# %%
plt.hist(Dataset["acceleration"])
plt.title("histograma de acceleracion")
plt.xlabel("aceleracion")
plt.ylabel("frecuencia")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(Dataset["displacement"], Dataset["horsepower"])

plt.title("Desplazamiento vs Caballos de fuerza")
plt.xlabel("Desplazamiento")
plt.ylabel("Caballos de fuerza")

plt.show()
